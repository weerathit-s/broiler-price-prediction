# %%
#graph and error

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
df = pd.read_excel('Monthly_budgetMAHARASHTRA_2021.xlsx')
df.index = df.index + 1
df.set_index('DATE', inplace=True)
df
# Out:
#                   UNIT       pred  Budget
# DATE
# 2021-01-31   56.083000  62.523057   71.50
# 2021-02-28   52.061667  50.667912   65.50
# 2021-03-31   80.982667  72.334622   69.50
# 2021-04-30   79.424000  80.030975   85.50
# 2021-05-31   71.194667  66.891516   95.00
# 2021-06-30   82.081000  60.351659   90.05
# 2021-07-31  108.452000  94.973548   70.10
# 2021-08-31   86.007000  89.184070   65.00
# 2021-09-30   98.516000  84.056727   65.00
# 2021-10-31   93.461667  82.685699   75.00
# 2021-11-30   79.067333  85.702224   70.00
# 2021-12-31   80.933667  76.374197   75.00

# %%
fig, ax = plt.subplots(figsize=(11, 4))
df['UNIT'].plot(ax=ax, label='true')
df['pred'].plot(ax=ax, label='predictions')
df['Budget'].plot(ax=ax, label='budget')
ax.legend()
