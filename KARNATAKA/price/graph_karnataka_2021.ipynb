# %%
#graph and error

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
df = pd.read_excel('Monthly_budgetKARNATAKA_2021.xlsx')
df.index = df.index + 1
df.set_index('DATE', inplace=True)
df
# Out:
#                   UNIT        pred     Budget
# DATE
# 2021-01-31   65.612000   61.378570  77.159024
# 2021-02-28   72.968000   62.893252  75.515092
# 2021-03-31  101.469667   90.257428  79.821936
# 2021-04-30   90.502333  102.738619  83.134869
# 2021-05-31   59.853333   61.174844  93.544401
# 2021-06-30   76.185667   71.638868  94.660407
# 2021-07-31  111.857667  101.028502  84.913070
# 2021-08-31  101.793667   90.331462  77.974993
# 2021-09-30  110.850000  101.910765  74.638533
# 2021-10-31  102.712667  108.297850  73.250615
# 2021-11-30   74.195667   74.320620  68.723913
# 2021-12-31   81.693667   83.021988  85.537369

# %%
fig, ax = plt.subplots(figsize=(11, 4))
df['UNIT'].plot(ax=ax, label='true')
df['pred'].plot(ax=ax, label='predictions')
df['Budget'].plot(ax=ax, label='budget')
ax.legend()
