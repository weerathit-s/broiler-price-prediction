# %%
#graph and error

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
df = pd.read_excel('Monthly_budgetKARNATAKA_2022.xlsx')
df.index = df.index + 1
df.set_index('DATE', inplace=True)
df
# Out:
#                   UNIT        pred  Budget
# DATE
# 2021-10-31  102.712667  109.412675   73.25
# 2021-11-30   74.195667   84.675678   68.72
# 2021-12-31   81.693667   89.448059   85.54
# 2022-01-31   84.512667   99.777737   92.00
# 2022-02-28   91.702000   83.492390   87.00
# 2022-03-31  130.515667  111.850149   82.00
# 2022-04-30  104.256667   90.081518   93.00
# 2022-05-31  121.430000  111.393599  102.00
# 2022-06-30  114.375000  111.631565   95.00
# 2022-07-31   85.187000  100.553365   89.00
# 2022-08-31   72.917333   80.695500   82.00
# 2022-09-30   86.678667   93.633918   91.00

# %%
fig, ax = plt.subplots(figsize=(11, 4))
df['UNIT'].plot(ax=ax, label='true')
df['pred'].plot(ax=ax, label='predictions')
df['Budget'].plot(ax=ax, label='budget')
ax.legend()
