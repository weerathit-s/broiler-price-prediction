# %%
#graph and error

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
df = pd.read_excel('Monthly_budgetMAHARASHTRA_2022.xlsx')
df.index = df.index + 1
df.set_index('DATE', inplace=True)
df
# Out:
#                   UNIT        pred  Budget
# DATE
# 2021-10-31   93.461667   98.313817   75.00
# 2021-11-30   79.067333   79.073543   70.00
# 2021-12-31   80.933667   78.702183   75.00
# 2022-01-31   81.159000   79.747138   83.91
# 2022-02-28   70.746333   62.692144   85.86
# 2022-03-31  114.178333   91.901795   80.77
# 2022-04-30   96.638000   86.787900   80.00
# 2022-05-31  114.207333   98.845542   87.81
# 2022-06-30  108.281000  100.155673   88.14
# 2022-07-31   70.707667   94.408305   88.27
# 2022-08-31   72.194333   75.586451   89.28
# 2022-09-30   99.058000   97.738051   88.42

# %%
fig, ax = plt.subplots(figsize=(11, 4))
df['UNIT'].plot(ax=ax, label='true')
df['pred'].plot(ax=ax, label='predictions')
df['Budget'].plot(ax=ax, label='budget')
ax.legend()
