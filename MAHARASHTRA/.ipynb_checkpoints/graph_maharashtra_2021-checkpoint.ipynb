# %%
#graph and error

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
df = pd.read_excel('Monthly_budgetMAHARASHTRA_2021.xlsx')
df.index = df.index + 1
df
# Out:
#          DATE        UNIT       pred  Budget
# 1  2021-01-31   56.083000  54.830968   71.50
# 2  2021-02-28   52.061667  45.641729   65.50
# 3  2021-03-31   80.982667  79.890901   69.50
# 4  2021-04-30   79.424000  87.304515   85.50
# 5  2021-05-31   71.194667  69.260392   95.00
# 6  2021-06-30   82.081000  62.276952   90.05
# 7  2021-07-31  108.452000  95.201144   70.10
# 8  2021-08-31   86.007000  84.347718   65.00
# 9  2021-09-30   98.516000  81.602975   65.00
# 10 2021-10-31   93.461667  92.671312   75.00
# 11 2021-11-30   79.067333  80.554147   70.00
# 12 2021-12-31   80.933667  69.343667   75.00

# %%
fig, ax = plt.subplots(figsize=(11, 4))
df['UNIT'].plot(ax=ax, label='true')
df['pred'].plot(ax=ax, label='predictions')
df['Budget'].plot(ax=ax, label='budget')
ax.legend()
